# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mapping = pd.read_csv("./data/gz2_filename_mapping.csv")

# %%
mapping.head()
# Out:
#                 objid    sample  asset_id
# 0  587722981736120347  original         1
# 1  587722981736579107  original         2
# 2  587722981741363294  original         3
# 3  587722981741363323  original         4
# 4  587722981741559888  original         5

# %%
#to jest źródło pochodzenia zdjęcia
mapping['sample'].value_counts()
# Out:
# sample
# original            245609
# stripe82_coadd_1     30346
# stripe82_coadd_2     30339
# extra                28174
# stripe82             21522
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
def display_image(i):
    filename = str(i) + '.jpg'
    path = './data/images_gz2/images/' + filename
    img = mpimg.imread(path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
display_image(456)
